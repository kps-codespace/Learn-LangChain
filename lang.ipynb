# %%
#Import PyPdf
from langchain_community.document_loaders import PyPDFLoader,WebBaseLoader,ArxivLoader
import bs4
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
#Read a PDF file using PyPDFLoader
text = PyPDFLoader("Transformers-paper.pdf")
doc = text.load()

# %%
print(doc)
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'Transformers-paper.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}, page_content='Provided proper attribution is provided, Google hereby grants permission to\nreproduce the tables and figures in this paper solely for use in journalistic or\nscholarly works.\nAttention Is All You Need\nAshish Vaswani∗\nGoogle Brain\navaswani@google.com\nNoam Shazeer∗\nGoogle Brain\nnoam@google.com\nNiki Parmar∗\nGoogle Research\nnikip@google.com\nJakob Uszkoreit∗\nGoogle Research\nusz@google.com\nLlion Jones∗\nGoogle Research\nllion@google.com\nAidan N. Gomez∗ †\nUniversity of Toronto\naidan@cs.toronto.edu\nŁukasz Kaiser∗\nGoogle Bra
# ...

# %%
#Read data from Web using WebBaseLoader
web = WebBaseLoader(web_paths=("https://www.langchain.ca/blog/",),
                     bs_kwargs=dict(parse_only=bs4.SoupStrainer(class_="gh-topic-content")))
doc_web = web.load()

# %%
print(doc_web)
print(doc_web.__len__())
# Out:
# [Document(metadata={'source': 'https://www.langchain.ca/blog/'}, page_content="\n\n\n\n\n\n\n\nMaster 18 Essential Docker Commands for Efficient Container Management\n\nDiscover 18 essential Docker commands to streamline container management and boost your workflow.\n\nVishal\nApr 3, 2025\n\n\n\n \n\n\n\n\n\n\nReSearch: Advancing LLM Reasoning with Reinforcement Learning and Search Integration\n\n\nVishal\nApr 2, 2025\n\n\n\n \n\n\n\n\n\n\nVideoMind: Revolutionizing Temporal-Grounded Video Reasoning with Chain-of-LoRA\n\n\nVishal\nApr 1, 2025\n\n\n\n \n\n\n\n\n\n\nOpen Deep Search: Revolutionizing Search-Enhanced AI with Open-Source Innovation\n\n\nVishal\nMar 28, 2025\n\n\n\n \n\n\n\n\n\n\nPLAN-AND-ACT: Revolutionizing AI Agents for Complex Tasks\n\n\nVishal\nMar 27, 2025\n\n\n\n \n\n\n\n\n\n\nAI Meets Style: Deep Learning-Powered Sunglass Color Customization\n\n\nVishal\nDec 16, 2024\n\n\n\n \n\n\n\n\n\n\nNeo4j vs. Elasticsearch: Vector Search, RAG, and LLM Integration\n\n\nVishal\
# ...

# %%
#Read from Arxiv international papaers website
#query is doc serial number
docs_Arxiv = ArxivLoader(query="1706.03762").load()

# %%
print(docs_Arxiv)
# Out:
# [Document(metadata={'Published': '2023-08-02', 'Title': 'Attention Is All You Need', 'Authors': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Lukasz Kaiser, Illia Polosukhin', 'Summary': 'The dominant sequence transduction models are based on complex recurrent or\nconvolutional neural networks in an encoder-decoder configuration. The best\nperforming models also connect the encoder and decoder through an attention\nmechanism. We propose a new simple network architecture, the Transformer, based\nsolely on attention mechanisms, dispensing with recurrence and convolutions\nentirely. Experiments on two machine translation tasks show these models to be\nsuperior in quality while being more parallelizable and requiring significantly\nless time to train. Our model achieves 28.4 BLEU on the WMT 2014\nEnglish-to-German translation task, improving over the existing best results,\nincluding ensembles by over 2 BLEU. On the WMT 2014 English-to-French\n
# ...

# %%
#character text spliiter
from langchain_text_splitters import  RecursiveCharacterTextSplitter

recuresivetextsplitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=200)
docs_chunk = recuresivetextsplitter.split_documents(docs_Arxiv)
print(docs_chunk)
# Out:
# [Document(metadata={'Published': '2023-08-02', 'Title': 'Attention Is All You Need', 'Authors': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Lukasz Kaiser, Illia Polosukhin', 'Summary': 'The dominant sequence transduction models are based on complex recurrent or\nconvolutional neural networks in an encoder-decoder configuration. The best\nperforming models also connect the encoder and decoder through an attention\nmechanism. We propose a new simple network architecture, the Transformer, based\nsolely on attention mechanisms, dispensing with recurrence and convolutions\nentirely. Experiments on two machine translation tasks show these models to be\nsuperior in quality while being more parallelizable and requiring significantly\nless time to train. Our model achieves 28.4 BLEU on the WMT 2014\nEnglish-to-German translation task, improving over the existing best results,\nincluding ensembles by over 2 BLEU. On the WMT 2014 English-to-French\n
# ...

# %%
# Charater splitter
from langchain_text_splitters import CharacterTextSplitter
charactertxtsplitter = CharacterTextSplitter(separator="\n\n \n\n",chunk_size=500, chunk_overlap=200)
docs_chunk2 = charactertxtsplitter.split_documents(doc_web)

# %%
docs_chunk2
# Out:
# [Document(metadata={'source': 'https://www.langchain.ca/blog/'}, page_content='Master 18 Essential Docker Commands for Efficient Container Management\n\nDiscover 18 essential Docker commands to streamline container management and boost your workflow.\n\nVishal\nApr 3, 2025\n\n\n\n \n\n\n\n\n\n\nReSearch: Advancing LLM Reasoning with Reinforcement Learning and Search Integration\n\n\nVishal\nApr 2, 2025\n\n\n\n \n\n\n\n\n\n\nVideoMind: Revolutionizing Temporal-Grounded Video Reasoning with Chain-of-LoRA\n\n\nVishal\nApr 1, 2025'),
# ...

# %%
# Read data from json file using JSONLoader
from langchain_community.document_loaders import JSONLoader
import json,requests
jsonData = requests.get("https://api.data.gov.in/resource/8d3b6596-b09e-4077-aebf-425193185a5b?api-key=579b464db66ec23bdd000001cdc3b564546246a772a26393094f5645&offset=0&limit=all&format=csv&format=json").json()

# %%
print(jsonData)
# Out:
# {'index_name': '8d3b6596-b09e-4077-aebf-425193185a5b', 'title': 'Monthly Crude Oil Processed by Refineries', 'desc': 'Monthly Crude Oil Processed by Refineries', 'created': 1687434829260, 'updated': 1750205724, 'created_date': '2023-06-22T17:24:31Z', 'updated_date': '2025-06-18T00:15:24Z', 'active': '1', 'visualizable': '1', 'catalog_uuid': 'ed4dbe82-439e-4e7f-b217-ce64627a49fc', 'source': 'data.gov.in', 'org_type': 'Central', 'org': ['Ministry of Petroleum and Natural Gas', 'Petroleum Planning & Analysis Cell (PPAC)'], 'sector': ['Non Renewable'], 'field': [{'name': 'Month', 'id': '_month_', 'type': 'keyword'}, {'name': 'Year', 'id': 'year', 'type': 'double'}, {'name': 'OIL COMPANIES', 'id': 'oil_companies_', 'type': 'keyword'}, {'name': 'Quantity (000 Metric Tonnes)', 'id': 'quantity_000_metric_tonnes_', 'type': 'double'}], 'target_bucket': {'index': 'api', 'type': 'ed4dbe82-439e-4e7f-b217-ce64627a49fc', 'field': '8d3b6596-b09e-4077-aebf-425193185a5b'}, 'message': 'Resource lists',
# ...

# %%
from langchain_text_splitters import RecursiveJsonSplitter

# %%
JsonSplitter = RecursiveJsonSplitter(max_chunk_size=200)
docs_json = JsonSplitter.create_documents(texts=[jsonData])

# %%
docs_json
# Out:
# [Document(metadata={}, page_content='{"index_name": "8d3b6596-b09e-4077-aebf-425193185a5b", "title": "Monthly Crude Oil Processed by Refineries", "desc": "Monthly Crude Oil Processed by Refineries", "created": 1687434829260}'),
#  Document(metadata={}, page_content='{"updated": 1750205724, "created_date": "2023-06-22T17:24:31Z", "updated_date": "2025-06-18T00:15:24Z", "active": "1", "visualizable": "1", "catalog_uuid": "ed4dbe82-439e-4e7f-b217-ce64627a49fc"}'),
#  Document(metadata={}, page_content='{"source": "data.gov.in", "org_type": "Central", "org": ["Ministry of Petroleum and Natural Gas", "Petroleum Planning & Analysis Cell (PPAC)"], "sector": ["Non Renewable"]}'),
# ...
